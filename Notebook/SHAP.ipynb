# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in c:\users\rathick a\anaconda3\lib\site-packages (0.52.0)
# Requirement already satisfied: numpy>=2 in c:\users\rathick a\anaconda3\lib\site-packages (from shap) (2.1.3)
# Requirement already satisfied: scipy in c:\users\rathick a\anaconda3\lib\site-packages (from shap) (1.15.3)
# Requirement already satisfied: scikit-learn in c:\users\rathick a\anaconda3\lib\site-packages (from shap) (1.6.1)
# Requirement already satisfied: pandas in c:\users\rathick a\anaconda3\lib\site-packages (from shap) (2.2.3)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\rathick a\anaconda3\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\rathick a\anaconda3\lib\site-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in c:\users\rathick a\anaconda3\lib\site-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in c:\users\rathick a\anaconda3\lib\site-packages (from shap) (0.61.0)
# Requirement already satisfied: llvmlite in c:\users\rathick a\anaconda3\lib\site-packages (from shap) (0.44.0)
# Requirement already satisfied: cloudpickle in c:\users\rathick a\anaconda3\lib\site-packages (from shap) (3.0.0)
# Requirement already satisfied: colorama in c:\users\rathick a\anaconda3\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rathick a\anaconda3\lib\site-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rathick a\anaconda3\lib\site-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rathick a\anaconda3\lib\site-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\rathick a\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rathick a\anaconda3\lib\site-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rathick a\anaconda3\lib\site-packages (from scikit-learn->shap) (3.5.0)

# %%
import shap

print(shap.__version__)
# Out:
# 0.52.0

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric="logloss"
)

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(
    n_estimators=300,
    learning_rate=0.05,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric="logloss"
)

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '0-keyshot_studio_win64_2025.3_14.2.2.1_update.exe', '1.stl', '11.log', '11.stl', '11.stp', '2.stl', '26IAT081029 (1).pdf', '26IAT081029 (2).pdf', '26IAT081029.pdf', '3.log', '3.stl', '3.stp', '4a639bd94a0cbde156f60e92d9f3eb522bf99f39f0f572b39dec6d9b2c56816b.pdf', '5a8a340ae62b7a95d3ff4eaa68df8bae17c718654c03240b6439cb3b029135e8.pdf', '6th round.pdf', '9.log', '9.stl', '9.stp', 'academic fees (1).pdf', 'academic fees.pdf', 'Admit Card.pdf', 'AdmitCard-260320107749.pdf', 'AdmitCard-260410605433 (1).pdf', 'AdmitCard-260410605433.pdf', 'Anaconda3-2025.06-0-Windows-x86_64.exe', 'aniragging undertaking by student.pdf', 'Anti DrugForm (1) (1).pdf', 'anti ragging.pdf', 'Antigravity-x64.exe', 'AntiraggingAffidavitForm.pdf', 'archive.zip', 'AssetFlow problem statement.pdfAssetFlow problem statement.pdf', 'BlueStacks10Installer_10.42.91.1001_native_b0b51421c4814aab3de3f23ac68816db_MzsxNSwwOzUsMTsxNSw0OzE1LDU7MTU=_SmlvSG90c3Rhcg==.exe', 'BOWLERSS (1).pptx', 'C codes', 'Car_Sales_Kaggle_DV0130EN_Lab1_Start.xlsx', 'Car_Sales_Kaggle_DV0130EN_Lab2_Start.xlsx', 'Car_Sales_Kaggle_DV0130EN_Lab3_Start.xlsx', 'CCR2_4grp.gcode', 'ChatGPT Installer (1).exe', 'ChatGPT Installer (2).exe', 'ChatGPT Installer.exe', 'ChoiceOrder_488844.pdf', 'ChromeSetup.exe', 'churn_model.joblib', 'Claude Setup (1).exe', 'Claude Setup.exe', 'Cloudflare_WARP_2026.6.850.0 (1).msi', 'Cloudflare_WARP_2026.6.850.0.msi', 'comet_installer_latest.exe', 'Creality_Slicer-4.8.2-build-291-win64.exe', 'CustomerLoyaltyProgram.csv', 'DARSHANA SIGNATURE .pdf', 'DARSHU PHOTO .pdf', 'DATA ANALYTICS PROJECT DOCUMENT.pdf', 'Data cleaning and preprocessing.ipynb', 'desktop.ini', 'Digi_fab_base.log', 'Digi_fab_base.stl', 'Digi_fab_base.stp', 'digi_fab_proj1.stl', 'digi_fab_proj3.stl', 'DiscordSetup.exe', 'Documents', 'EcoSphere ESG Management Platform.pdf', 'EDA (1).ipynb', 'EDA (2).ipynb', 'EDA.ipynb', 'exit from josaa.pdf', 'fee payment details (1).pdf', 'fee payment details.pdf', 'fees_receipt_2026jul-nov.pdf', 'final_destination_G4.gcode', 'Git-2.55.0.2-64-bit.exe', 'GitHubDesktopSetup-x64.exe', 'habit-tracker.jpg', 'Hostel_Mess_Fee_2026_JUL-NOV.pdf', 'html2pdf.zip', 'image from the LFM simulator - www.myscope.training (1).jpg', 'image from the LFM simulator - www.myscope.training (10).jpg', 'image from the LFM simulator - www.myscope.training (2).jpg', 'image from the LFM simulator - www.myscope.training (3).jpg', 'image from the LFM simulator - www.myscope.training (4).jpg', 'image from the LFM simulator - www.myscope.training (5).jpg', 'image from the LFM simulator - www.myscope.training (6).jpg', 'image from the LFM simulator - www.myscope.training (7).jpg', 'image from the LFM simulator - www.myscope.training (8).jpg', 'image from the LFM simulator - www.myscope.training (9).jpg', 'image from the LFM simulator - www.myscope.training.jpg', 'Image to PDF 20250722 13.45.58.pdf', 'Image to PDF 20250722 13.48.40.pdf', 'Image to PDF 20250722 13.50.20.pdf', 'Image to PDF 20250722 13.51.28.pdf', 'Image to PDF 20250722 13.52.44.pdf', 'Image to PDF 20250722 13.57.59.pdf', 'Image to PDF 20250722 14.00.40.pdf', 'Image to PDF 20250722 20.40.52.pdf', 'Image to PDF 20250722 21.04.15.pdf', 'Image to PDF 20250722 21.05.28.pdf', 'Image to PDF 20250723 12.46.16.pdf', 'imaging1.ipynb', 'in.gov.cbse-HSCER-206540932025.pdf', 'in.gov.cbse-SSCER-201786602023.pdf', 'in.gov.cbse-SSMGR-201786602023.pdf', 'in.gov.transport-DRVLC-TN7020260005217.pdf', 'in.gov.uidai-ADHAR-d2e7ec26345893f3e364f263193db1cc.pdf', 'indian_startup_funding_Lab1.xlsx', 'Install-Free Fire MAX-GooglePlayGames.exe', 'jee information bulletin.pdf', 'Lecture_0.pptx', 'Lecture_2.pptx', 'Microsoft.Services.Store.winmd', 'Miniconda3-latest-Windows-x86_64.exe', 'Mobile Devices', 'Modelling.ipynb', 'mos_q_pic.jpg', 'msys2-x86_64-20251213.exe', 'NEET (UG) - 2026.html', 'NEET (UG) - 2026.pdf', 'NEET (UG) - 2026_files', 'neet-refund pdf.pdf', 'OllamaSetup.exe', 'online+retail.zip', 'PASSPORT SIZE PHOTO 1.jpeg', 'PASSPORT SIZ ...

# %%
import joblib

model = joblib.load("churn_model.joblib")

print(type(model))
# Out:
# <class 'dict'>

# %%
print(model.keys())
# Out:
# dict_keys(['preprocessor', 'model', 'feature_columns'])

# %%
xgb_model = model["model"]

print(type(xgb_model))
# Out:
# <class 'sklearn.linear_model._logistic.LogisticRegression'>

# %%
feature_columns = model["feature_columns"]

print(len(feature_columns))
print(feature_columns)
# Out:
# 27
# ['Count', 'Country', 'State', 'City', 'Zip Code', 'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charges', 'Total Charges']

# %%
preprocessor = model["preprocessor"]

print(type(preprocessor))
# Out:
# <class 'sklearn.compose._column_transformer.ColumnTransformer'>

# %%
import pandas as pd

df = pd.read_excel("Telco_customer_churn.xlsx")

print(df.shape)
print(df.columns.tolist())
# Out:
# (7043, 33)
# ['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code', 'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure Months', 'Phone Service', 'Multiple Lines', 'Internet Service', 'Online Security', 'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value', 'Churn Score', 'CLTV', 'Churn Reason']

# %%
X_raw = df[feature_columns]

print(X_raw.shape)
print(X_raw.head())
# Out:
# (7043, 27)
#    Count        Country       State         City  Zip Code  \
# 0      1  United States  California  Los Angeles     90003
# 1      1  United States  California  Los Angeles     90005
# 2      1  United States  California  Los Angeles     90006
# 3      1  United States  California  Los Angeles     90010
# 4      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  ...  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No  ...
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No  ...
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No  ...
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No  ...
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No  ...
#
#   Online Backup Device Protection  Tech Support Streaming TV Streaming Movies  \
# 0           Yes                No            No           No               No
# 1            No                No            No           No               No
# 2            No               Yes            No          Yes              Yes
# 3            No               Yes           Yes          Yes              Yes
# 4           Yes               Yes            No          Yes              Yes
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes               Mailed check
# 1  Month-to-month               Yes           Electronic check
# 2  Month-to-month               Yes           Electronic check
# 3  Month-to-month               Yes           Electronic check
# 4  Month-to-month               Yes  Bank transfer (automatic)
#
#   Monthly Charges Total Charges
# 0           53.85        108.15
# 1           70.70        151.65
# 2           99.65         820.5
# 3          104.80       3046.05
# 4          103.70        5036.3
#
# [5 rows x 27 columns]

# %%
import numpy as np
import pandas as pd

# %%
d = pd.read_csv(r"C:\Users\RATHICK A\OneDrive\Desktop\data analytics\data\telco_customer_churn_processed_for_modelling.csv")

# %%
X_processed = preprocessor.transform(X_raw)

print(X_processed.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22776\2104061690.py in ?()
# ----> 1 X_processed = preprocessor.transform(X_raw)
#       2
#       3 print(X_processed.shape)
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, **params)
#    1097             routed_params = process_routing(self, "transform", **params)
#    1098         else:
#    1099             routed_params = self._get_empty_routing()
#    1100
# -> 1101         Xs = self._call_func_on_transformers(
#    1102             X,
#    1103             None,
#    1104             _transform_one,
#
# ~\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, y, func, column_as_labels, routed_params)
#     912         except ValueError as e:
#     913             if "Expected 2D array, got 1D array instead" in str(e):
#     914                 raise ValueError(_ERR_MSG_1DCOLUMN) from e
#     915             else:
# --> 916                 raise
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py in ?(self, iterable)
#      73         iterable_with_config = (
#      74             (_with_config(delayed_func, config), args, kwargs)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#
# ~\anaconda3\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1914             # If n_jobs==1, run the computation sequentially and return
#    1915             # immediately to avoid overheads.
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#    1921         # call is interrupted early and that the same instance is immediately
#
# ~\anaconda3\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1857         finally:
#    1858             self.print_progress()
#    1859             self._running = False
#    1860             self._iterating = False
# -> 1861             self._original_iterator = None
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py in ?(self, *args, **kwargs)
#     135                 UserWarning,
#     136             )
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\pipeline.py in ?(transformer, X, y, weight, params)
#    1527         Parameters to be passed to the transformer's ``transform`` method.
#    1528
#    1529         This should be of the form ``process_routing()["step_name"]``.
#    1530     """
# -> 1531     res = transformer.transform(X, **params.transform)
#    1532     # if we have a weight for this transformer, multiply output
#    1533     if weight is None:
#    1534         return res
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, copy)
#    1058         """
#    1059         check_is_fitted(self)
#    1060
#    1061         copy = copy if copy is not None else self.copy
# -> 1062         X = validate_data(
#    1063             self,
#    1064             X,
#    1065             reset=False,
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2940             out = y
#    2941         else:
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#    2947     else:
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: ' '

# %%
# Convert Total Charges to numeric
# Blank spaces will become NaN
df["Total Charges"] = pd.to_numeric(df["Total Charges"], errors="coerce")

print(df["Total Charges"].isna().sum())
# Out:
# 11

# %%
X_processed = preprocessor.transform(X_raw)

print(X_processed.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22776\1616596086.py in ?()
# ----> 1 X_processed = preprocessor.transform(X_raw)
#       2
#       3 print(X_processed.shape)
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, **params)
#    1097             routed_params = process_routing(self, "transform", **params)
#    1098         else:
#    1099             routed_params = self._get_empty_routing()
#    1100
# -> 1101         Xs = self._call_func_on_transformers(
#    1102             X,
#    1103             None,
#    1104             _transform_one,
#
# ~\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py in ?(self, X, y, func, column_as_labels, routed_params)
#     912         except ValueError as e:
#     913             if "Expected 2D array, got 1D array instead" in str(e):
#     914                 raise ValueError(_ERR_MSG_1DCOLUMN) from e
#     915             else:
# --> 916                 raise
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py in ?(self, iterable)
#      73         iterable_with_config = (
#      74             (_with_config(delayed_func, config), args, kwargs)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#
# ~\anaconda3\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1914             # If n_jobs==1, run the computation sequentially and return
#    1915             # immediately to avoid overheads.
#    1916             output = self._get_sequential_output(iterable)
#    1917             next(output)
# -> 1918             return output if self.return_generator else list(output)
#    1919
#    1920         # Let's create an ID that uniquely identifies the current call. If the
#    1921         # call is interrupted early and that the same instance is immediately
#
# ~\anaconda3\Lib\site-packages\joblib\parallel.py in ?(self, iterable)
#    1857         finally:
#    1858             self.print_progress()
#    1859             self._running = False
#    1860             self._iterating = False
# -> 1861             self._original_iterator = None
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\parallel.py in ?(self, *args, **kwargs)
#     135                 UserWarning,
#     136             )
#     137             config = {}
#     138         with config_context(**config):
# --> 139             return self.function(*args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\pipeline.py in ?(transformer, X, y, weight, params)
#    1527         Parameters to be passed to the transformer's ``transform`` method.
#    1528
#    1529         This should be of the form ``process_routing()["step_name"]``.
#    1530     """
# -> 1531     res = transformer.transform(X, **params.transform)
#    1532     # if we have a weight for this transformer, multiply output
#    1533     if weight is None:
#    1534         return res
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#     322             return_tuple = (
#
# ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py in ?(self, X, copy)
#    1058         """
#    1059         check_is_fitted(self)
#    1060
#    1061         copy = copy if copy is not None else self.copy
# -> 1062         X = validate_data(
#    1063             self,
#    1064             X,
#    1065             reset=False,
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2940             out = y
#    2941         else:
#    2942             out = X, y
#    2943     elif not no_val_X and no_val_y:
# -> 2944         out = check_array(X, input_name="X", **check_params)
#    2945     elif no_val_X and not no_val_y:
#    2946         out = _check_y(y, **check_params)
#    2947     else:
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1052                         )
#    1053                     array = xp.astype(array, dtype, copy=False)
#    1054                 else:
#    1055                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1056             except ComplexWarning as complex_warning:
#    1057                 raise ValueError(
#    1058                     "Complex data not supported\n{}\n".format(array)
#    1059                 ) from complex_warning
#
# ~\anaconda3\Lib\site-packages\sklearn\utils\_array_api.py in ?(array, dtype, order, copy, xp, device)
#     835         # Use NumPy API to support order
#     836         if copy is True:
#     837             array = numpy.array(array, order=order, dtype=dtype)
#     838         else:
# --> 839             array = numpy.asarray(array, order=order, dtype=dtype)
#     840
#     841         # At this point array is a NumPy ndarray. We convert it to an array
#     842         # container that is consistent with the input's namespace.
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, dtype, copy)
#    2149     def __array__(
#    2150         self, dtype: npt.DTypeLike | None = None, copy: bool_t | None = None
#    2151     ) -> np.ndarray:
#    2152         values = self._values
# -> 2153         arr = np.asarray(values, dtype=dtype)
#    2154         if (
#    2155             astype_is_view(values.dtype, arr.dtype)
#    2156             and using_copy_on_write()
#
# ValueError: could not convert string to float: ' '
